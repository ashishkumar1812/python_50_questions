# %%
given = "2226"
add = 0
for i in given:
    add = add + int(i)
print(add)
# Out:
# 12

# %%
given = 2226
add = 0
while given > 0:
        add = add + given % 10
        given = given // 10
print(add)
# Out:
# 12

# %%
class SumOfDigits:
    def __init__(self):
        print("This class calculates the sum of digits of a number.")

    def sum_of_digits(self, user_input: int) -> int:
        """
        Find the sum of digits of a given number.

        Args:
            user_input (int): Non-negative integer

        Returns:
            int: Sum of digits

        Raises:
            TypeError: If input is not an integer
            ValueError: If number is negative
        """
        # type check
        if not isinstance(user_input, int):
            raise TypeError("Input must be an integer.")

        # negative number check
        if user_input < 0:
            raise ValueError("Number must be non-negative.")

        total = 0
        while user_input > 0:
            total += user_input % 10
            user_input //= 10

        return total


# main execution
if __name__ == "__main__":
    try:
        user_input = int(input("Enter a number: "))

        obj = SumOfDigits()
        result = obj.sum_of_digits(user_input)

        print(f"Sum of digits is: {result}")

    except (TypeError, ValueError) as e:
        print(e)
    except Exception as e:
        print("Something went wrong:", e)
# Out:
# Enter a number:  741
# This class calculates the sum of digits of a number.
# Sum of digits is: 12
